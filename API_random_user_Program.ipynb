# %% [markdown]
# <a href="https://colab.research.google.com/github/Luya123/Ai-Chatbots-project/blob/main/API_random_user_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests #random API program

url = "https://randomuser.me/api"

response = requests.get(url)
data = response.json()

user = data["results"][0]

print(user["name"]["first"])
print(user["email"])
print(user["location"]["country"])
# Out:
# Marinho
# marinho.barros@example.com
# Brazil

# %%
import requests #random API program

url = "https://randomuser.me/api"

response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'results': [{'gender': 'female', 'name': {'title': 'Ms', 'first': 'Connie', 'last': 'Fletcher'}, 'location': {'street': {'number': 6951, 'name': 'Shady Ln Dr'}, 'city': 'Bathurst', 'state': 'New South Wales', 'country': 'Australia', 'postcode': 4244, 'coordinates': {'latitude': '-83.3159', 'longitude': '120.3763'}, 'timezone': {'offset': '+3:30', 'description': 'Tehran'}}, 'email': 'connie.fletcher@example.com', 'login': {'uuid': '34c9bc13-dce8-40b7-aad7-3e1455db4d2c', 'username': 'heavyduck888', 'password': 'spoons', 'salt': 'W6FdQEQP', 'md5': '1d9c4fd6109adf0e395d362cbbaec730', 'sha1': '43bc683d175222a5976fb07279495409fa11935b', 'sha256': '9389cd5b4c9c31c034fc2f56cb7e6c77456b0a3166be922c555df63046b00451'}, 'dob': {'date': '1950-09-07T22:02:17.672Z', 'age': 75}, 'registered': {'date': '2008-02-16T07:30:28.603Z', 'age': 18}, 'phone': '03-8628-1711', 'cell': '0480-047-327', 'id': {'name': 'TFN', 'value': '955682415'}, 'picture': {'large': 'https://randomuser.me/api/portraits/women/36
# ...
